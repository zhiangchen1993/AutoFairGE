# %%
import pandas as pd
df = pd.read_csv('Census_test_race.csv')

# %%
df.describe()
# Out:
#                age    workclass       fnlwgt    education  education-num  \
# count  4521.000000  4521.000000  4521.000000  4521.000000    4521.000000
# mean      0.161838     0.021353    -0.006383     0.064015       0.187650
# std       0.963667     1.022500     0.969422     0.930010       1.002966
# min      -1.593000    -2.873900    -1.666600    -2.663500      -3.545100
# 25%      -0.560500     0.040700    -0.676600    -0.332600      -0.420300
# 50%       0.103200     0.040700    -0.097300     0.185400      -0.029600
# 75%       0.840700     0.040700     0.446300     0.444400       1.142200
# max       3.790600     2.955200     7.233900     1.221400       2.314000
#
#        marital-status   occupation  relationship          sex  capital-gain  \
# count     4521.000000  4521.000000   4521.000000  4521.000000   4521.000000
# mean        -0.121665     0.038483     -0.148315     0.127573      0.192022
# std          0.892687     0.998005      1.029319     0.944419      1.357314
# ...
